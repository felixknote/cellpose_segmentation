# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from scipy import stats
from scipy.stats import gaussian_kde, mannwhitneyu, ttest_ind
from itertools import combinations
import os
import random
import re 
import seaborn as sns
import ptitprince as pt
# Define paths
plate_map_path = r"E:\Data\2025_04_22 60xWIA 1.5x CRISPRi mCh\sharpest_slice\03_segmentation\plate_map.xlsx"
data_folder = r"E:\Data\2025_04_22 60xWIA 1.5x CRISPRi mCh\sharpest_slice\03_segmentation\cyto3_gpu_results"
output_folder = data_folder

# %%
# Load the plate map
plate_map = pd.read_excel(plate_map_path, header=None)
plate_map.index = range(len(plate_map))
plate_map.index.name = None
print("Loaded Plate Map:")
print(plate_map)
# Out:
# Loaded Plate Map:
#         0         1         2         3         4         5        6   \
# 0  mCh_1M0   mCh_1M1   mCh_1M2   mCh_1M3   mCh_1M4   mCh_1M5  mCh_1M6
# 1  mCh_1M9  mCh_1M10  mCh_1M11  mCh_1M12  mCh_1M13  mCh_1M14     -ATC
# 2  mCh_1M0   mCh_1M1   mCh_1M2   mCh_1M3   mCh_1M4   mCh_1M5  mCh_1M6
# 3  mCh_1M9  mCh_1M10  mCh_1M11  mCh_1M12  mCh_1M13  mCh_1M14     -ATC
# 4  mCh_1M0   mCh_1M1   mCh_1M2   mCh_1M3   mCh_1M4   mCh_1M5  mCh_1M6
# 5  mCh_1M9  mCh_1M10  mCh_1M11  mCh_1M12  mCh_1M13  mCh_1M14     -ATC
# 6  mCh_1M0   mCh_1M1   mCh_1M2   mCh_1M3   mCh_1M4   mCh_1M5  mCh_1M6
# 7  mCh_1M9  mCh_1M10  mCh_1M11  mCh_1M12  mCh_1M13  mCh_1M14     -ATC
#
#         7     8     9     10    11
# 0  mCh_1M7  -ATC  AV08  AV08  AV08
# 1     -ATC  -ATC  AV08  AV08  AV08
# 2  mCh_1M7  -ATC  AV08  AV08  AV08
# 3     -ATC  -ATC  AV08  AV08  AV08
# 4  mCh_1M7  -ATC  AV08  AV08  AV08
# 5     -ATC  -ATC  AV08  AV08  AV08
# 6  mCh_1M7  -ATC  AV08  AV08  AV08
# ...

# %%
# Function to count replicates
def count_replicates(plate_map):
    replicate_counts = plate_map.stack().value_counts()
    return replicate_counts
replicate_counts = count_replicates(plate_map)
print("\nReplicate Counts:")
print(replicate_counts)
# Out:
# Replicate Counts:
# AV08        24
# -ATC        16
# mCh_1M0      4
# mCh_1M1      4
# mCh_1M2      4
# mCh_1M3      4
# mCh_1M4      4
# mCh_1M5      4
# mCh_1M6      4
# mCh_1M7      4
# mCh_1M9      4
# mCh_1M10     4
# mCh_1M11     4
# mCh_1M12     4
# mCh_1M13     4
# mCh_1M14     4
# Name: count, dtype: int64

# %%
# Define controls *BEFORE* loading and aggregating data
controls = ['-ATC', 'GCMC']

# %%
# Parse filenames and load data
def parse_filename(filename):
    """
    Extracts well and Z position from filenames like:
    'Stack_WellA01_ChannelCam-DIA DIC Master_Seq0000_Z1_stacked_masks'
    Returns: well (e.g., 'A01'), position (e.g., '1')
    """
    well_match = re.search(r'Well([A-H]\d{2})', filename)
    z_match = re.search(r'_Z(\d+)', filename)
    if not well_match or not z_match:
        raise ValueError(f"Filename '{filename}' does not match expected format.")
    well = well_match.group(1)
    position = z_match.group(1)
    return well, position

# %%
def load_data(data_folder, plate_map):
    data = []
    for file in os.listdir(data_folder):
        if file.endswith(".xlsx") and file != "plate_map.xlsx":
            try:
                well, position = parse_filename(file)
                df = pd.read_excel(os.path.join(data_folder, file))
                df["Well"] = well
                df["Position"] = position
                # Row: 'A' -> 0, 'B' -> 1, etc.
                row_idx = ord(well[0].upper()) - ord('A')
                # Col: '01' -> 0, '12' -> 11, etc.
                col_idx = int(well[1:]) - 1
                if (0 <= row_idx < len(plate_map)) and (0 <= col_idx < len(plate_map.columns)):
                    df["Label"] = plate_map.iloc[row_idx, col_idx]
                else:
                    df["Label"] = np.nan
                data.append(df)
            except Exception as e:
                print(f"Skipping file '{file}' due to error: {e}")
    if data:
        return pd.concat(data, ignore_index=True)
    else:
        return None  # Explicitly return None if no valid data

# --- LOAD DATA ---
data = load_data(data_folder, plate_map)

# --- ONLY PROCEED IF DATA WAS LOADED ---
if data is not None:
    print("Data loaded successfully. Proceeding with analysis.")
    print(data.dtypes)  # Print the data types of the DataFrame
    print(data.head())  # Print the head of the DataFrame
else:
    print("No data loaded. Cannot proceed with analysis.")
    exit()
# Out:
# Data loaded successfully. Proceeding with analysis.
# Label              object
# Area                int64
# Length            float64
# Width             float64
# Roundness         float64
# Aspect Ratio      float64
# Mean Intensity    float64
# Centroid X        float64
# Centroid Y        float64
# Type               object
# Well               object
# Position           object
# dtype: object
#      Label  Area     Length      Width  Roundness  Aspect Ratio  \
# 0  mCh_1M0  1027  44.529815  32.085417   0.655672      1.387852
# 1  mCh_1M0   604  28.934779  26.589213   0.940376      1.088215
# 2  mCh_1M0   820  50.654073  23.306365   0.528453      2.173401
# 3  mCh_1M0  1495  51.976299  36.822236   0.875720      1.411547
# 4  mCh_1M0  1554  58.456802  33.987049   0.842726      1.719973
#
#    Mean Intensity   Centroid X  Centroid Y    Type Well Position
# 0     1250.582278  2863.854917   15.195716  Object  A01       10
# ...

# %%
# Aggregate statistics for plotting
def aggregate_statistics(data, controls):
    print(f"Data columns: {data.columns}")  # Print columns to debug  
    # Convert 'Label' column to string type
    data['Label'] = data['Label'].astype(str) 
    grouped = data[~data['Label'].isin(controls)].groupby("Label") # Exclude controls from groupby
    stats = grouped.agg({
        "Area": ["mean", "std"],
        "Roundness": ["mean", "std"],
        "Mean Intensity": ["mean", "std"],
        "Width": ["mean", "std"],
        "Length": ["mean", "std"],
    }).reset_index()

    # Flatten the MultiIndex columns
    stats.columns = [
        "Label", 
        "Area Mean", "Area STD",
        "Roundness Mean", "Roundness STD",
        "Mean Intensity Mean", "Mean Intensity STD",
        "Width Mean", "Width STD",
        "Length Mean", "Length STD",
    ]
    # Append Control stats to stats dataframe
    control_stats = data[data['Label'].isin(controls)].groupby("Label").agg({
        "Area": ["mean", "std"],
        "Roundness": ["mean", "std"],
        "Mean Intensity": ["mean", "std"],
        "Width": ["mean", "std"],
        "Length": ["mean", "std"],
    }).reset_index()
    
    control_stats.columns = [
        "Label", 
        "Area Mean", "Area STD",
        "Roundness Mean", "Roundness STD",
        "Mean Intensity Mean", "Mean Intensity STD",
        "Width Mean", "Width STD",
        "Length Mean", "Length STD",
    ]
    stats = pd.concat([stats,control_stats], ignore_index=True)
    return stats
try:
    stats = aggregate_statistics(data, controls)
except Exception as e:
    print(f"Error during aggregation: {e}")
    stats = aggregate_statistics(data, [])
# Out:
# Data columns: Index(['Label', 'Area', 'Length', 'Width', 'Roundness', 'Aspect Ratio',
#        'Mean Intensity', 'Centroid X', 'Centroid Y', 'Type', 'Well',
#        'Position'],
#       dtype='object')

# %%
# Sort the labels in the desired order
def custom_sort(label):
    match = re.match(r'mCh_(\d+)M(\d+)', str(label))  # Ensure label is a string
    if match:
        group = int(match.group(1))
        member = int(match.group(2))
        return (group, member)
    return (float('inf'), float('inf'))

# Apply custom sorting directly and sort
stats['sort_key'] = stats['Label'].apply(custom_sort)
stats = stats.sort_values(by='sort_key')
stats = stats.drop('sort_key', axis=1)  # Remove the temporary column
stats = stats.reset_index(drop=True)
print(stats)
# Out:
#        Label     Area Mean       Area STD  Roundness Mean  Roundness STD  \
# 0    mCh_1M0  45088.062622  625478.999681        0.857882       1.692188
# 1    mCh_1M1  19064.010062  399714.638226        0.811869       1.203870
# 2    mCh_1M2  23935.175566  448203.550625        0.841925       1.499959
# 3    mCh_1M3  11565.568339  301360.282068        0.811155       1.273419
# 4    mCh_1M4  24256.716921  451919.377326        0.800067       1.347455
# 5    mCh_1M5  75789.473684  812748.366957        0.900146       1.980182
# 6    mCh_1M6  68710.485506  774216.655854        0.923685       2.047297
# 7    mCh_1M7  20638.503708  414457.210569        0.788167       1.266031
# 8    mCh_1M9  35776.397516  554449.013459        0.854884       1.680237
# 9   mCh_1M10  16774.419011  371455.227854        0.800318       1.115720
# 10  mCh_1M11  12345.414407  312842.671381        0.793093       0.965640
# 11  mCh_1M12  10952.027836  291924.224413        0.796338       1.203071
# ...

# %% [markdown]
# # Plot Comparison #

# %%
def plot_comparison(stats, data, metric, output_folder, controls=[], max_points_per_group=750):
    # Sort stats
    stats = stats.copy()
    stats['sort_key'] = stats['Label'].apply(custom_sort)
    stats = stats.sort_values(by='sort_key').drop(columns='sort_key').reset_index(drop=True)

    # Sample data per group
    data = data.copy()
    sampled_data = []
    for label in stats['Label']:
        subset = data[data['Label'] == label]
        if metric in subset.columns:
            sampled_data.append(subset.sample(min(len(subset), max_points_per_group), random_state=42))
    plot_data = pd.concat(sampled_data, ignore_index=True)

    # Set style
    sns.set(style="whitegrid", font_scale=1.2)

    # Color palette
    palette = dict(zip(stats['Label'], sns.color_palette("Reds", len(stats))))

    # Plot setup
    fig_width = max(16, 0.6 * len(stats))
    fig, ax = plt.subplots(figsize=(fig_width, 8))
    sns.violinplot(
        x="Label", y=metric, data=plot_data,
        order=stats['Label'], palette=palette,
        cut=2, inner=None, linewidth=1.2, width=1.0, ax=ax
    )

    # Overlay means and add connecting lines
    mean_values = stats[f"{metric} Mean"].values
    ax.scatter(range(len(stats)), mean_values, color="black", s=60, label="Group Mean", zorder=3)
    
    # Add lines connecting the mean points
    ax.plot(range(len(stats)), mean_values, color="black", lw=1.5, zorder=2)

    # Axis formatting
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=14)
    ax.set_ylabel(metric, fontsize=16)
    ax.set_xlabel("Label", fontsize=16)

    # Set y-axis limits: lower limit is 0, upper limit adjusts automatically
    ax.set_ylim(bottom=0)

    # Add legend inside the plot without overlapping
    ax.legend(loc='upper right', fontsize=12, frameon=True)

    # Save and show
    plt.tight_layout()
    output_path = os.path.join(output_folder, f"{metric}_comparison_seaborn.svg")
    plt.savefig(output_path, format="svg", bbox_inches="tight")
    print(f"Saved plot: {output_path}")
    plt.show()

# %% [markdown]
# # Violin Scatter Plot Comparison #

# %%
def plot_violin_scatter(stats, data, metric, output_folder, controls=[], max_points_per_group=750, lower_quantile=0.05, upper_quantile=0.95):
    # Sort stats DataFrame based on custom_sort function
    stats = stats.copy()
    stats['sort_key'] = stats['Label'].apply(custom_sort)
    stats = stats.sort_values(by='sort_key').reset_index(drop=True)
    stats = stats.drop('sort_key', axis=1)

    # Prepare data for plotting
    data = data.copy()
    data['GroupType'] = data['Label'].apply(lambda x: 'Control' if x in controls else 'Non-control')

    # Limit points per group and remove outliers using quantiles
    sampled_data = []
    for label in stats['Label']:
        subset = data[data['Label'] == label]
        if metric in subset.columns and not subset.empty:
            # Quantile filtering to remove outliers
            lower = subset[metric].quantile(lower_quantile)
            upper = subset[metric].quantile(upper_quantile)
            subset = subset[(subset[metric] >= lower) & (subset[metric] <= upper)]
            # Limit points per group
            if len(subset) > max_points_per_group:
                subset = subset.sample(max_points_per_group, random_state=42)
            sampled_data.append(subset)
    if not sampled_data:
        print("No data to plot after filtering.")
        return
    plot_data = pd.concat(sampled_data, ignore_index=True)

    # Set style
    sns.set(style="whitegrid", font_scale=1.2)
    plt.figure(figsize=(12, 8))

    # Color palette
    palette = dict(zip(stats['Label'], sns.color_palette("Reds", len(stats))))

    # Calculate jitter width based on density for each group
    jitter_x = []
    for label in stats['Label']:
        subset = plot_data[plot_data['Label'] == label]
        if len(subset) > 1:
            fig, ax = plt.subplots()
            sns.kdeplot(subset[metric], bw_adjust=0.5, fill=False, ax=ax)
            line = ax.lines[0]
            x_kde, y_kde = line.get_data()
            plt.close(fig)
            max_width = 0.3
            ykdemax = y_kde.max()
            if ykdemax < 1e-12:  # Avoid division by zero or near-zero
                density_norm = np.full_like(y_kde, max_width * 0.1)
            else:
                density_norm = y_kde / ykdemax * max_width
            jitter_vals = np.interp(subset[metric], x_kde, density_norm)
            # Replace NaN or inf with zero
            jitter_vals = np.nan_to_num(jitter_vals, nan=0.0, posinf=0.0, neginf=0.0)
            jitter_x.extend(jitter_vals)
        else:
            jitter_x.extend([0] * len(subset))

    # Create x positions with density-proportional jitter
    x_positions = []
    jitter_idx = 0
    for i, label in enumerate(stats['Label']):
        count = len(plot_data[plot_data['Label'] == label])
        group_jitter = jitter_x[jitter_idx:jitter_idx+count]
        group_jitter = np.array(group_jitter)
        # Ensure no negative or absurdly large jitters
        group_jitter = np.clip(group_jitter, 0, 0.5)
        x_vals = i + np.random.uniform(-group_jitter, group_jitter)
        x_positions.extend(x_vals)
        jitter_idx += count

    # Plot scatter with jittered positions
    ax = plt.gca()
    pos_idx = 0
    for i, label in enumerate(stats['Label']):
        subset = plot_data[plot_data['Label'] == label]
        n = len(subset)
        x_vals = x_positions[pos_idx:pos_idx + n]
        pos_idx += n
        ax.scatter(x_vals, subset[metric], color=palette[label],
                   edgecolor='black', s=100, label=label, alpha=0.7)

    # Overlay group means and connecting lines
    means = stats[f"{metric} Mean"]
    ax.scatter(range(len(stats['Label'])), means, color="black", s=60,
               label="Group Mean", zorder=3)
    ax.plot(range(len(stats['Label'])), means, color="black", lw=1.5, zorder=2)

    # Configure axes and save
    plt.xticks(range(len(stats['Label'])), stats['Label'],
               rotation=45, ha="right", fontsize=24)
    plt.ylabel(metric, fontsize=24)
    plt.xlabel("Label", fontsize=24)
    plt.grid(axis='y', linestyle='--', linewidth=0.7, alpha=0.6)
    plt.ylim(bottom=0)
    plt.tight_layout()
    plt.legend(loc='upper right', frameon=True, fontsize=18)

    output_path = os.path.join(output_folder, f"{metric}_scatter.svg")
    plt.savefig(output_path, format="svg")
    print(f"Saved plot: {output_path}")
    plt.show()

# %%
def plot_mean_intensity_vs_cell_width(stats, data, output_folder, max_points_per_group=1000, jitter_strength=0.2):
    q_low_intensity = data["Mean Intensity"].quantile(0.01)
    q_high_intensity = data["Mean Intensity"].quantile(0.99)
    q_low_width = data["Width"].quantile(0.01)
    q_high_width = data["Width"].quantile(0.99)
    filtered_data = data[
        (data["Mean Intensity"] >= q_low_intensity) & (data["Mean Intensity"] <= q_high_intensity) &
        (data["Width"] >= q_low_width) & (data["Width"] <= q_high_width)
    ]
    intensity_range = q_high_intensity - q_low_intensity
    width_range = q_high_width - q_low_width
    x_min = q_low_intensity - 0.1 * intensity_range
    x_max = q_high_intensity + 0.1 * intensity_range
    y_min = q_low_width - 0.1 * width_range
    y_max = q_high_width + 0.1 * width_range
    plt.figure(figsize=(10, 6))
    colors = cm.Reds(np.linspace(0.4, 0.9, len(stats)))
    for label, color in zip(stats["Label"], colors):
        subset = filtered_data[filtered_data["Label"] == label]
        if "Mean Intensity" in subset.columns and "Width" in subset.columns:
            if len(subset) > max_points_per_group:
                subset = subset.sample(max_points_per_group, random_state=42)
            jittered_x = subset["Mean Intensity"] + np.random.uniform(-jitter_strength, jitter_strength, size=len(subset))
            plt.scatter(jittered_x, subset["Width"], color=color, alpha=0.4, s=15, label=label)
    means_intensity = stats["Mean Intensity Mean"]
    means_width = stats["Width Mean"]
    stds_intensity = stats["Mean Intensity STD"]
    stds_width = stats["Width STD"]
    plt.errorbar(means_intensity, means_width, xerr=stds_intensity, yerr=stds_width,
                 fmt='o', color="black", ecolor="black", capsize=5, label="Mean ± STD", markersize=5)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xlabel("Mean Intensity", fontsize=24)
    plt.ylabel("Width", fontsize=24)
    plt.xlim(q_low_intensity, q_high_intensity)
    plt.ylim(0 , q_high_width)
    plt.legend(loc='upper right')
    plt.tight_layout()
    output_path = os.path.join(output_folder, "Mean_Intensity_vs_Width_filtered.svg")
    plt.savefig(output_path,format="svg")
    print(f"Saved plot: {output_path}")

# %%
def plot_mean_intensity_vs_cell_length(stats, data, output_folder, max_points_per_group=1500, jitter_strength=0.2):
    q_low_intensity = data["Mean Intensity"].quantile(0.01)
    q_high_intensity = data["Mean Intensity"].quantile(0.99)
    q_low_length = data["Length"].quantile(0.01)
    q_high_length = data["Length"].quantile(0.99)
    filtered_data = data[
        (data["Mean Intensity"] >= q_low_intensity) & (data["Mean Intensity"] <= q_high_intensity) &
        (data["Length"] >= q_low_length) & (data["Length"] <= q_high_length)
    ]
    plt.figure(figsize=(10, 6))
    colors = cm.Reds(np.linspace(0.4, 0.9, len(stats)))
    for label, color in zip(stats["Label"], colors):
        subset = filtered_data[filtered_data["Label"] == label]
        if "Mean Intensity" in subset.columns and "Length" in subset.columns:
            if len(subset) > max_points_per_group:
                subset = subset.sample(max_points_per_group, random_state=42)
            jittered_x = subset["Mean Intensity"] + np.random.uniform(-jitter_strength, jitter_strength, size=len(subset))
            plt.scatter(jittered_x, subset["Length"], color=color, alpha=0.4, s=10, label=label)

    means_intensity = stats["Mean Intensity Mean"]
    means_length = stats["Length Mean"]
    stds_intensity = stats["Mean Intensity STD"]
    stds_length = stats["Length STD"]
    
    plt.errorbar(means_intensity, means_length, xerr=stds_intensity, yerr=stds_length,
                 fmt='o', color="black", ecolor="black", capsize=5, label="Mean ± STD", markersize=5)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xlabel("Mean Intensity", fontsize=24)
    plt.ylabel("Length", fontsize=12)
    plt.xlim(q_low_intensity, q_high_intensity)
    plt.ylim(0, q_high_length)
    plt.legend(loc='upper right')
    plt.tight_layout()
    output_path = os.path.join(output_folder, "Mean_Intensity_vs_Length_filtered.svg")
    plt.savefig(output_path,format="svg")
    print(f"Saved plot: {output_path}")

# %%
def plot_relative_intensity_vs_cell_width(stats, data, output_folder, controls=['-ATC', 'GCMC'], max_points_per_group=1000, jitter_strength=0.2):
    if not controls:
        print("No controls specified. Skipping relative intensity plot.")
        return
    q_low_intensity = data["Mean Intensity"].quantile(0.01)
    q_high_intensity = data["Mean Intensity"].quantile(0.99)
    q_low_width = data["Width"].quantile(0.01)
    q_high_width = data["Width"].quantile(0.99)
    filtered_data = data[
        (data["Mean Intensity"] >= q_low_intensity) & (data["Mean Intensity"] <= q_high_intensity) &
        (data["Width"] >= q_low_width) & (data["Width"] <= q_high_width)
    ]
    # Fix SettingWithCopyWarning by creating an explicit copy
    filtered_data = filtered_data.copy()
    control_mean_intensity = stats[stats["Label"].isin(controls)]["Mean Intensity Mean"].mean()
    filtered_data["Relative Intensity"] = filtered_data["Mean Intensity"] / control_mean_intensity
    plt.figure(figsize=(10, 6))
    # Recalculate stats for relative intensity
    stats_relative = filtered_data.groupby("Label").agg({
        "Relative Intensity": ["mean", "std"],
        "Width": ["mean", "std"],
    }).reset_index()
    stats_relative.columns = [
        "Label",
        "Relative Intensity Mean", "Relative Intensity STD",
        "Width Mean", "Width STD",
    ]
    colors = cm.Reds(np.linspace(0.4, 0.9, len(stats)))
    for label, color in zip(stats["Label"], colors):
        subset = filtered_data[filtered_data["Label"] == label]
        if "Relative Intensity" in subset.columns and "Width" in subset.columns:
            if len(subset) > max_points_per_group:
                subset = subset.sample(max_points_per_group, random_state=42)
            jittered_x = subset["Relative Intensity"] + np.random.uniform(-jitter_strength, jitter_strength, size=len(subset))
            plt.scatter(jittered_x, subset["Width"], color=color, alpha=0.4, s=15, label=label)
    means_intensity = stats_relative["Relative Intensity Mean"]
    means_width = stats_relative["Width Mean"]
    stds_intensity = stats_relative["Relative Intensity STD"]
    stds_width = stats_relative["Width STD"]
    plt.errorbar(means_intensity, means_width, xerr=stds_intensity, yerr=stds_width,
                 fmt='o', color="black", ecolor="black", capsize=5, label="Mean ± STD", markersize=5)
    # Dynamic x-axis limits
    x_min = filtered_data["Relative Intensity"].quantile(0.01)  # 1st percentile
    x_max = filtered_data["Relative Intensity"].quantile(0.99)  # 99th percentile
    x_range = x_max - x_min
    # Add padding to the range
    x_min = max(0, x_min - 0.1 * x_range)
    x_max += 0.1 * x_range
    plt.xlim(x_min, x_max)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xlabel("Relative Intensity (vs Control)", fontsize=24)
    plt.ylabel("Width", fontsize=12)
    plt.legend(loc='upper right')
    plt.tight_layout() 
    output_path = os.path.join(output_folder, "Relative_Intensity_vs_Width_filtered.svg")
    plt.savefig(output_path,format="svg")
    print(f"Saved plot: {output_path}")

# %%
def plot_relative_intensity_vs_cell_length(stats, data, output_folder, controls=['-ATC', 'GCMC'], max_points_per_group=1500, jitter_strength=0.2):
    if not controls:
        print("No controls specified. Skipping relative intensity plot.")
        return
    q_low_intensity = data["Mean Intensity"].quantile(0.01)
    q_high_intensity = data["Mean Intensity"].quantile(0.99)
    q_low_length = data["Length"].quantile(0.01)
    q_high_length = data["Length"].quantile(0.99)
    filtered_data = data[
        (data["Mean Intensity"] >= q_low_intensity) & (data["Mean Intensity"] <= q_high_intensity) &
        (data["Length"] >= q_low_length) & (data["Length"] <= q_high_length)
    ]
    # Fix SettingWithCopyWarning by creating an explicit copy
    filtered_data = filtered_data.copy()
    control_mean_intensity = stats[stats["Label"].isin(controls)]["Mean Intensity Mean"].mean()
    filtered_data["Relative Intensity"] = filtered_data["Mean Intensity"] / control_mean_intensity
    plt.figure(figsize=(10, 6))
    # Recalculate stats for relative intensity
    stats_relative = filtered_data.groupby("Label").agg({
        "Relative Intensity": ["mean", "std"],
        "Length": ["mean", "std"],
    }).reset_index()
    stats_relative.columns = [
        "Label",
        "Relative Intensity Mean", "Relative Intensity STD",
        "Length Mean", "Length STD",
    ]
    colors = cm.Reds(np.linspace(0.4, 0.9, len(stats)))
    for label, color in zip(stats["Label"], colors):
        subset = filtered_data[filtered_data["Label"] == label]
        if "Relative Intensity" in subset.columns and "Length" in subset.columns:
            if len(subset) > max_points_per_group:
                subset = subset.sample(max_points_per_group, random_state=42)
            jittered_x = subset["Relative Intensity"] + np.random.uniform(-jitter_strength, jitter_strength, size=len(subset))
            plt.scatter(jittered_x, subset["Length"], color=color, alpha=0.4, s=10, label=label)
    means_intensity = stats_relative["Relative Intensity Mean"]
    means_length = stats_relative["Length Mean"]
    stds_intensity = stats_relative["Relative Intensity STD"]
    stds_length = stats_relative["Length STD"]
    plt.errorbar(means_intensity, means_length, xerr=stds_intensity, yerr=stds_length,
                 fmt='o', color="black", ecolor="black", capsize=5, label="Mean ± STD", markersize=5)
    # Dynamic x-axis limits
    x_min = filtered_data["Relative Intensity"].quantile(0.01)  # 1st percentile
    x_max = filtered_data["Relative Intensity"].quantile(0.99)  # 99th percentile
    x_range = x_max - x_min
    # Add padding to the range
    x_min = max(0, x_min - 0.1 * x_range)
    x_max += 0.1 * x_range
    plt.xlim(x_min, x_max)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xlabel("Relative Intensity (vs Control)", fontsize=24)
    plt.ylabel("Width", fontsize=12)
    plt.legend(loc='upper right')
    plt.tight_layout()
    plt.xlim(x_min, x_max)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xlabel("Relative Intensity (vs Control)", fontsize=24)

# %%
def plot_roundness_vs_relative_intensity(stats, data, output_folder, controls=['-ATC', 'GCMC'], max_points_per_group=1000, jitter_strength=0.2):
    if not controls:
        print("No controls specified. Skipping relative intensity plot.")
        return
    # Filter data based on quantiles to exclude outliers
    q_low_intensity = data["Mean Intensity"].quantile(0.01)
    q_high_intensity = data["Mean Intensity"].quantile(0.99)
    q_low_roundness = data["Roundness"].quantile(0.01)
    q_high_roundness = data["Roundness"].quantile(0.99)
    filtered_data = data[
        (data["Mean Intensity"] >= q_low_intensity) & (data["Mean Intensity"] <= q_high_intensity) &
        (data["Roundness"] >= q_low_roundness) & (data["Roundness"] <= q_high_roundness)
    ]
    # Fix SettingWithCopyWarning by creating an explicit copy
    filtered_data = filtered_data.copy()
    control_mean_intensity = stats[stats["Label"].isin(controls)]["Mean Intensity Mean"].mean()
    filtered_data["Relative Intensity"] = filtered_data["Mean Intensity"] / control_mean_intensity
    plt.figure(figsize=(10, 6))
    # Recalculate stats for relative intensity
    stats_relative = filtered_data.groupby("Label").agg({
        "Relative Intensity": ["mean", "std"],
        "Roundness": ["mean", "std"],
    }).reset_index()
    stats_relative.columns = [
        "Label",
        "Relative Intensity Mean", "Relative Intensity STD",
        "Roundness Mean", "Roundness STD",
    ]
    colors = cm.Reds(np.linspace(0.4, 0.9, len(stats)))

    for label, color in zip(stats["Label"], colors):
        subset = filtered_data[filtered_data["Label"] == label]
        if "Relative Intensity" in subset.columns and "Roundness" in subset.columns:
            if len(subset) > max_points_per_group:
                subset = subset.sample(max_points_per_group, random_state=42)
            jittered_x = subset["Relative Intensity"] + np.random.uniform(-jitter_strength, jitter_strength, size=len(subset))
            plt.scatter(jittered_x, subset["Roundness"], color=color, alpha=0.4, s=10, label=label)
    means_intensity = stats_relative["Relative Intensity Mean"]
    means_roundness = stats_relative["Roundness Mean"]
    stds_intensity = stats_relative["Relative Intensity STD"]
    stds_roundness = stats_relative["Roundness STD"]
    plt.errorbar(means_intensity, means_roundness, xerr=stds_intensity, yerr=stds_roundness,
                 fmt='o', color="black", ecolor="black", capsize=5, label="Mean ± STD", markersize=5)
    # Dynamic x-axis limits
    x_min = filtered_data["Relative Intensity"].quantile(0.01)  # 1st percentile
    x_max = filtered_data["Relative Intensity"].quantile(0.99)  # 99th percentile
    x_range = x_max - x_min
    # Add padding to the range
    x_min = max(0, x_min - 0.1 * x_range)
    x_max += 0.1 * x_range
    plt.xlim(x_min, x_max)
    # Dynamic y-axis limits
    y_min = filtered_data["Roundness"].quantile(0.01)  # 1st percentile
    y_max = filtered_data["Roundness"].quantile(0.99)  # 99th percentile
    y_range = y_max - y_min
    # Add padding to the range
    y_min -= 0.1 * y_range
    y_max += 0.1 * y_range
    plt.ylim(y_min, y_max)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xlabel("Relative Intensity (vs Control)", fontsize=12)
    plt.ylabel("Roundness", fontsize=12)
    plt.legend(loc='upper right')
    plt.tight_layout()
    output_path = os.path.join(output_folder, "Roundness_vs_Relative_Intensity_filtered.svg")
    plt.savefig(output_path,format="svg")
    print(f"Saved plot: {output_path}")

# %%
def plot_mean_intensity_histogram(data, output_folder, controls=[]):
    q_low_intensity = data["Mean Intensity"].quantile(0.01)
    q_high_intensity = data["Mean Intensity"].quantile(0.99)
    plt.figure(figsize=(10, 6))
    labels = data['Label'].unique()
    colors = [plt.cm.Reds(i) for i in np.linspace(0.4, 0.9, len(labels))]
    # Setting bin count
    bin_count = 100
    # Creating bins
    bins = np.linspace(q_low_intensity, q_high_intensity, bin_count)
    for color, label in zip(colors, labels):
        subset = data[(data['Label'] == label) & (data["Mean Intensity"] >= q_low_intensity) & (data["Mean Intensity"] <= q_high_intensity)]['Mean Intensity']
        # Calculate histogram values
        hist, _ = np.histogram(subset, bins=bins)
        # Normalize the histogram so the peak is at 1
        if np.sum(hist) > 0:
            hist_normalized = hist / float(np.max(hist))
        else:
            hist_normalized = hist
        # Plotting the normalized histogram
        bin_centers = (bins[:-1] + bins[1:]) / 2
        bin_width = bins[1] - bins[0]
        plt.bar(bin_centers, hist_normalized, width=bin_width, alpha=0.7, label=label, color=color)
        # Add outline using KDE
        kde = gaussian_kde(subset)
        x_vals = np.linspace(q_low_intensity, q_high_intensity, 500)
        y_vals = kde(x_vals)
        if np.max(y_vals) > 0:
            y_vals_normalized = y_vals / np.max(y_vals)
            plt.plot(x_vals, y_vals_normalized, color='black', linewidth=1.2)
    plt.xlabel("Mean Intensity", fontsize=24)
    plt.ylabel("Normalized Frequency", fontsize=24)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.legend(loc='upper right')
    # Generate major tick locations
    min_val = q_low_intensity
    max_val = q_high_intensity
    range_vals = max_val - min_val
    step = 10 ** np.floor(np.log10(range_vals / 7))  # Aim for roughly 7 ticks
    start = min_val - min_val % step
    ticks = np.arange(start, max_val + step, step)
    # Filter the ticks to only include numbers in the data range
    ticks = ticks[(ticks >= min_val) & (ticks <= max_val)]
    plt.xticks(ticks, rotation=45, ha="right")
    plt.tight_layout()
    output_path = os.path.join(output_folder, "Mean_Intensity_Histogram.svg")
    plt.savefig(output_path)
    print(f"Saved plot: {output_path}")

# %% [markdown]
# # Main #

# %%
# Generate plots for Area, Roundness, and Mean Intensity
if 'stats' in locals() and not stats.empty:
    plot_comparison(stats, data, "Area", output_folder, controls=controls)
    plot_comparison(stats, data, "Roundness", output_folder, controls=controls)
    plot_comparison(stats, data, "Mean Intensity", output_folder, controls=controls)
    #Scatter
    plot_violin_scatter(stats, data, "Area", output_folder, controls=controls)
    plot_violin_scatter(stats, data, "Roundness", output_folder, controls=controls)
    plot_violin_scatter(stats, data, "Mean Intensity", output_folder, controls=controls)
    
    #plot_mean_intensity_vs_cell_width(stats, data, output_folder)
    #plot_mean_intensity_vs_cell_length(stats, data, output_folder)
    #plot_relative_intensity_vs_cell_width(stats, data, output_folder, controls=controls)
    #plot_relative_intensity_vs_cell_length(stats, data, output_folder, controls=controls)
    #plot_roundness_vs_relative_intensity(stats, data, output_folder, controls=controls)
    
    #plot_mean_intensity_histogram(data, output_folder, controls=controls)
else:
    print("Stats is either not defined or empty. No plots will be generated.")
# Out:
# Saved plot: E:\Data\2025_04_22 60xWIA 1.5x CRISPRi mCh\sharpest_slice\03_segmentation\cyto3_gpu_results\Area_comparison_seaborn.svg
# Saved plot: E:\Data\2025_04_22 60xWIA 1.5x CRISPRi mCh\sharpest_slice\03_segmentation\cyto3_gpu_results\Roundness_comparison_seaborn.svg
# Saved plot: E:\Data\2025_04_22 60xWIA 1.5x CRISPRi mCh\sharpest_slice\03_segmentation\cyto3_gpu_results\Mean Intensity_comparison_seaborn.svg
# Saved plot: E:\Data\2025_04_22 60xWIA 1.5x CRISPRi mCh\sharpest_slice\03_segmentation\cyto3_gpu_results\Area_scatter.svg
# Saved plot: E:\Data\2025_04_22 60xWIA 1.5x CRISPRi mCh\sharpest_slice\03_segmentation\cyto3_gpu_results\Roundness_scatter.svg
# Saved plot: E:\Data\2025_04_22 60xWIA 1.5x CRISPRi mCh\sharpest_slice\03_segmentation\cyto3_gpu_results\Mean Intensity_scatter.svg
